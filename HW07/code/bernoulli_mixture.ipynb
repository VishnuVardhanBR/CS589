# %% [markdown]
# ### Question 1: Bernoulli Mixture

# %%
import numpy as np

# %% [markdown]
# ### Load model and data

# %%
data = np.load("bernoulli.npz")
phi  = data["phi"]
pi   = data["pi"]
x    = data["x"]
K,D  = phi.shape

# %% [markdown]
# ### Question 1 (b,c)

# %%
#Add your code here

# %% [markdown]
# ### Question 1 (d,e)

# %%
#Add your code here
